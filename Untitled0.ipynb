# %% [markdown]
# <a href="https://colab.research.google.com/github/jet9kd/DS2022/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/jet9kd/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 109 (delta 37), reused 30 (delta 30), pack-reused 63 (from 1)
# Receiving objects: 100% (109/109), 657.47 KiB | 10.60 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# ...
# Download complete
# Extracting data files...
# Data extracted
